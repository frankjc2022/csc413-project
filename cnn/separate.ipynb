# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./2021_Residential_cnn.csv')
# self.data.iloc[idx, 2] price
# draw the price distribution
plt.hist(data.iloc[:, 2], bins=20)
plt.xlabel('price')
plt.ylabel('count')
plt.title('price distribution')
plt.show()

# %%
# split into 20 columns uniform distribution
bins = pd.qcut(data.iloc[:, 2], [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1])
print(bins)
# Out:
# 0           (610000.0, 701940.0]
# 1        (2400000.0, 27500000.0]
# 2         (1680000.0, 1900000.0]
# 3        (2400000.0, 27500000.0]
# 4        (2400000.0, 27500000.0]
#                   ...
# 93650       (610000.0, 701940.0]
# 93651       (900000.0, 945000.0]
# 93652       (610000.0, 701940.0]
# 93653      (14999.999, 610000.0]
# 93654     (1900000.0, 2400000.0]
# Name: Sp_dol, Length: 93655, dtype: category
# Categories (20, interval[float64, right]): [(14999.999, 610000.0] < (610000.0, 701940.0] < (701940.0, 765000.0] < (765000.0, 820000.0] ... (1531000.0, 1680000.0] < (1680000.0, 1900000.0] < (1900000.0, 2400000.0] < (2400000.0, 27500000.0]]
